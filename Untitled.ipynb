# %%
import os
import tempfile
import logging
from urllib.parse import unquote
from pathlib import Path
from dotenv import load_dotenv

# Docling imports
from docling.document_converter import DocumentConverter

# LangChain imports
from langchain_text_splitters import MarkdownHeaderTextSplitter
from langchain_openai import AzureOpenAIEmbeddings
from langchain_community.vectorstores import FAISS

# Azure Storage imports
from azure.storage.blob import BlobServiceClient

# %%
converter = DocumentConverter()
result = converter.convert("LC-GAN.pdf")
# Out:
# [INFO] 2026-02-27 22:16:58,589 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-27 22:16:58,601 [RapidOCR] download_file.py:60: File exists and is valid: /home/matrix4284/miniconda3/envs/azure_rag_app/lib/python3.12/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-02-27 22:16:58,602 [RapidOCR] main.py:53: Using /home/matrix4284/miniconda3/envs/azure_rag_app/lib/python3.12/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-02-27 22:16:58,687 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-27 22:16:58,690 [RapidOCR] download_file.py:60: File exists and is valid: /home/matrix4284/miniconda3/envs/azure_rag_app/lib/python3.12/site-packages/rapidocr/models/ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2026-02-27 22:16:58,690 [RapidOCR] main.py:53: Using /home/matrix4284/miniconda3/envs/azure_rag_app/lib/python3.12/site-packages/rapidocr/models/ch_ppocr_mobile_v2.0_cls_infer.onnx
# ...

# %%
from markitdown import MarkItDown

# Initialize the MarkItDown converter
# For basic text extraction from PDFs, no LLM client is strictly necessary
md_converter = MarkItDown()

# Path to your PDF file
pdf_path = "LC-GAN.pdf"

# Convert the PDF to Markdown
try:
    result = md_converter.convert(pdf_path)
    markdown_content = result.text_content
    
    # Define the output file path
    output_path = "output_document.md"

    # Save the Markdown content to a file
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(markdown_content)

    print(f"PDF conversion completed. Output saved to {output_path}")

except Exception as e:
    print(f"An error occurred during conversion: {e}")
# Out:
# PDF conversion completed. Output saved to output_document.md
